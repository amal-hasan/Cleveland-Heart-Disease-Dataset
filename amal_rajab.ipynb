# %% [markdown]
# #   مجموعة بيانات: Cleveland Heart Disease Dataset

# %%
# !wget -q --no-check-certificate \
  'https://www.kaggle.com/api/v1/datasets/download/ritwikb3/heart-disease-cleveland' \
  -O 'data.zip'

# !unzip -q 'data.zip'

# %%
import pandas as pd


df = pd.read_csv('Heart_disease_cleveland_new.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   0       145   233    1        2      150      0      2.3      2
# 1   67    1   3       160   286    0        2      108      1      1.5      1
# 2   67    1   3       120   229    0        2      129      1      2.6      1
# 3   37    1   2       130   250    0        0      187      0      3.5      2
# 4   41    0   1       130   204    0        2      172      0      1.4      0
#
#    ca  thal  target
# 0   0     2       0
# 1   3     1       1
# 2   2     3       1
# 3   0     1       0
# 4   0     1       0

# %%
df.shape
# Out:
# (303, 14)

# %%
print(f"عدد الصفوف: {df.shape[0]}")
print(f"عدد الأعمدة: {df.shape[1]}")
# Out:
# عدد الصفوف: 303
# عدد الأعمدة: 14

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    2.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    2.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    2.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    3.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.990099  149.607261    0.326733    1.039604    0.600660    0.663366
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
print(f"عدد الصفوف المكررة: {df.duplicated().sum()}")
df.drop_duplicates(inplace=True)
# Out:
# عدد الصفوف المكررة: 0

# %%
numerical_cols = df.select_dtypes(include=['number']).columns
for col in numerical_cols:
    if df[col].isnull().any():
        df[col] = df[col].fillna(df[col].mean())

# %% [markdown]
# عرض المصابين الذين لديهم مرض قلبي و أعمارهم أكبر من 50

# %%
filtered_df = df[(df['target'] == 1) & (df['age'] > 50)]
print(filtered_df.head())
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 1   67    1   3       160   286    0        2      108      1      1.5      1
# 2   67    1   3       120   229    0        2      129      1      2.6      1
# 6   62    0   3       140   268    0        2      160      0      3.6      2
# 8   63    1   3       130   254    0        2      147      0      1.4      1
# 9   53    1   3       140   203    1        2      155      1      3.1      2
#
#    ca  thal  target
# 1   3     1       1
# 2   2     3       1
# 6   2     1       1
# 8   1     3       1
# 9   0     3       1

# %%
fil=df[(df['age'] < 18) | (df['age'] > 100)]
fil.head()
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []

# %%
df.loc[(df['trestbps'] < 80) | (df['trestbps'] > 200)]
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []

# %% [markdown]
# ## توزيع المرضى حسب الجنس

# %%
gender_counts = df['sex'].value_counts()
print("عدد الذكور والإناث:")
print(gender_counts)
# Out:
# عدد الذكور والإناث:
# sex
# 1    206
# 0     97
# Name: count, dtype: int64

# %% [markdown]
# ## نسبة الاصابة بالمرض حسب الجنس

# %%
gender_disease = df.groupby('sex')['target'].value_counts(normalize=True).unstack()
print("نسبة الإصابة حسب الجنس:")
gender_disease
# Out:
# نسبة الإصابة حسب الجنس:
# target         0         1
# sex
# 0       0.742268  0.257732
# 1       0.446602  0.553398

# %% [markdown]
# ## توزيع العمر بين المرضى وغير المرضى

# %%
age_summary = df.groupby('target')['age'].describe()
age_summary
# Out:
#         count       mean       std   min    25%   50%   75%   max
# target
# 0       164.0  52.585366  9.511957  29.0  44.75  52.0  59.0  76.0
# 1       139.0  56.625899  7.938416  35.0  52.00  58.0  62.0  77.0

# %% [markdown]
# ## معدل الكوليسترول حسب وجود المرض

# %%
chol_summary = df.groupby('target')['chol'].describe()

chol_summary
# Out:
#         count        mean        std    min     25%    50%     75%    max
# target
# 0       164.0  241.042683  46.879084  126.0  208.75  234.5  267.25  371.0
# 1       139.0  250.942446  47.964777  131.0  217.50  249.0  283.50  371.0

# %% [markdown]
# ## استخدام IQR لتحديد القيم المتطرفة ووضع حد أقصى لها

# %%
for col in ['age', 'trestbps', 'chol', 'thalach', 'oldpeak']:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df[col] = df[col].clip(lower=lower_bound, upper=upper_bound)  # Cap outliers

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    2.158416  131.346535  245.584158    0.148515
# std      9.038662    0.467299    0.960126   16.648749   47.558803    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    2.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    2.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    3.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    3.000000  170.000000  371.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.990099  149.652640    0.326733    1.024422    0.600660    0.663366
# ...

# %% [markdown]
# ## تغيير نوع بعض الأعمدة

# %%
categorical_cols = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']
for col in categorical_cols:
    df[col] = df[col].astype('category')

# %%
for col in categorical_cols:
    print(f"{col}: {df[col].unique()}")
# Out:
# sex: [1, 0]
# Categories (2, int64): [0, 1]
# cp: [0, 3, 2, 1]
# Categories (4, int64): [0, 1, 2, 3]
# fbs: [1, 0]
# Categories (2, int64): [0, 1]
# restecg: [2, 0, 1]
# Categories (3, int64): [0, 1, 2]
# exang: [0, 1]
# Categories (2, int64): [0, 1]
# slope: [2, 1, 0]
# Categories (3, int64): [0, 1, 2]
# ca: [0, 3, 2, 1]
# Categories (4, int64): [0, 1, 2, 3]
# thal: [2, 1, 3]
# Categories (3, int64): [1, 2, 3]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    category
#  2   cp        303 non-null    category
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    category
#  6   restecg   303 non-null    category
#  7   thalach   303 non-null    float64
#  8   exang     303 non-null    category
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    category
#  11  ca        303 non-null    category
#  12  thal      303 non-null    category
#  13  target    303 non-null    int64
# dtypes: category(8), float64(2), int64(4)
# memory usage: 17.8 KB

# %%
df['sex'].value_counts()
df.groupby('sex')['target'].mean()
# Out:
# <ipython-input-27-b6d7c1322249>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('sex')['target'].mean()
# sex
# 0    0.257732
# 1    0.553398
# Name: target, dtype: float64

# %%
pd.crosstab(df['cp'], df['target'])
# Out:
# target   0    1
# cp
# 0       16    7
# 1       41    9
# 2       68   18
# 3       39  105

# %%
print(df['cp'].value_counts())
# Out:
# cp
# 3    144
# 2     86
# 1     50
# 0     23
# Name: count, dtype: int64

# %% [markdown]
# ## نسبة الإصابة بالمرض لكل نوع ألم صدر

# %%
# عدد الإصابات وعدم الإصابة حسب نوع ألم الصدر
cp_target = pd.crosstab(df['cp'], df['target'], normalize='index')
cp_target
# Out:
# target         0         1
# cp
# 0       0.695652  0.304348
# 1       0.820000  0.180000
# 2       0.790698  0.209302
# 3       0.270833  0.729167

# %%
#حساب متوسط العمر لكل نوع slope
print(df.groupby('slope')['age'].mean())
# Out:
# slope
# 0    52.661972
# 1    56.100000
# 2    55.380952
# Name: age, dtype: float64
# <ipython-input-32-a8d9fe74a8d1>:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   print(df.groupby('slope')['age'].mean())
